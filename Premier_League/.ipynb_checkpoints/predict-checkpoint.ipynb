# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv("matches.csv",index_col=0)

# %%
df.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W   2   0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   2
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W   3   0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W   2   1
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   2   1
#
#          opponent  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0.0   0.0
# 1  Leicester City  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0.0   0.0
# 2     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0.0   0.0
# 3          Fulham  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0.0   0.0
# 4     Aston Villa  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0.0   0.0
#
#    season     team
# 0    2022  Arsenal
# 1    2022  Arsenal
# 2    2022  Arsenal
# 3    2022  Arsenal
# 4    2022  Arsenal
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2280 entries, 0 to 41
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2280 non-null   object
#  1   time          2280 non-null   object
#  2   comp          2280 non-null   object
#  3   round         2280 non-null   object
#  4   day           2280 non-null   object
#  5   venue         2280 non-null   object
#  6   result        2280 non-null   object
#  7   gf            2280 non-null   int64
#  8   ga            2280 non-null   int64
#  9   opponent      2280 non-null   object
#  10  xg            2280 non-null   float64
#  11  xga           2280 non-null   float64
#  12  poss          2280 non-null   float64
#  13  attendance    1582 non-null   float64
#  14  captain       2280 non-null   object
#  15  formation     2280 non-null   object
#  16  referee       2280 non-null   object
#  17  match report  2280 non-null   object
#  18  notes         0 non-null      float64
#  19  sh            2280 non-null   float64
#  20  sot           2280 non-null   float64
#  21  dist          2279 non-null   float64
#  22  fk            2280 non-null   float64
#  23  pk            2280 non-null   float64
#  24  pkatt         2280 non-null   float64
#  25  season        2280 non-null   int64
#  26  team          2280 non-null   object
# dtypes: float64(11), int64(3), object(13)
# memory usage: 498.8+ KB

# %%
df['season'].value_counts()
# Out:
# 2022    760
# 2021    760
# 2020    760
# Name: season, dtype: int64

# %%
38*20*3
# Out:
# 2280

# %%
df['team'].value_counts()
# Out:
# Arsenal                     114
# Leicester City              114
# Wolverhampton Wanderers     114
# West Ham United             114
# Tottenham Hotspur           114
# Southampton                 114
# Newcastle United            114
# Manchester United           114
# Aston Villa                 114
# Liverpool                   114
# Manchester City             114
# Leeds United                114
# Everton                     114
# Crystal Palace              114
# Chelsea                     114
# Brighton and Hove Albion    114
# Fulham                       76
# Brentford                    76
# Burnley                      76
# Nottingham Forest            38
# Bournemouth                  38
# Norwich City                 38
# Watford                      38
# Sheffield United             38
# West Bromwich Albion         38
# Name: team, dtype: int64

# %%
df['round'].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 29    60
# Matchweek 12    60
# Matchweek 24    60
# Matchweek 25    60
# Matchweek 7     60
# Matchweek 26    60
# Matchweek 27    60
# Matchweek 28    60
# Matchweek 30    60
# Matchweek 2     60
# Matchweek 31    60
# Matchweek 32    60
# Matchweek 33    60
# Matchweek 34    60
# Matchweek 35    60
# Matchweek 36    60
# Matchweek 37    60
# Matchweek 23    60
# Matchweek 22    60
# Matchweek 21    60
# Matchweek 20    60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 8     60
# Matchweek 9     60
# Matchweek 10    60
# Matchweek 11    60
# Matchweek 13    60
# Matchweek 14    60
# Matchweek 15    60
# Matchweek 16    60
# Matchweek 17    60
# Matchweek 18    60
# Matchweek 19    60
# Matchweek 38    60
# Name: round, dtype: int64

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['venue_code']= df['venue'].astype('category').cat.codes

# %%
df['opp_code'] =  df['opponent'].astype('category').cat.codes

# %%
df['hour'] = df['time'].str.replace(":.+","", regex=True).astype('int')

# %%
df['day_code'] = df['date'].dt.dayofweek

# %%
df['target'] = (df['result']=='W').astype('int')

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = df[df['date']< '2023-01-01']

# %%
test =  df[df['date'] > '2023-01-01']

# %%
predictors = ["venue_code","opp_code","hour","day_code"]

# %%
rf.fit(train[predictors],train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
acc = accuracy_score(test['target'],preds)

# %%
acc
# Out:
# 0.5864485981308412

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
pd.crosstab(index=combined['actual'],columns=combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           207  56
# 1           121  44

# %%
precision_score(test['target'],preds)
# Out:
# 0.44

# %%
grouped_matches = df.groupby("team")

# %%
group = grouped_matches.get_group("Tottenham Hotspur")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2022-08-06  15:00  Premier League   Matchweek 1  Sat  Home      W   4   1
# 1  2022-08-14  16:30  Premier League   Matchweek 2  Sun  Away      D   2   2
# 2  2022-08-20  12:30  Premier League   Matchweek 3  Sat  Home      W   1   0
# 3  2022-08-28  16:30  Premier League   Matchweek 4  Sun  Away      W   2   0
# 4  2022-08-31  19:45  Premier League   Matchweek 5  Wed  Away      D   1   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 54 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Home      W   4   0
# 55 2021-05-08  12:30  Premier League  Matchweek 35  Sat  Away      L   1   3
# 56 2021-05-16  14:05  Premier League  Matchweek 36  Sun  Home      W   2   0
# 57 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Home      L   1   2
# 58 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Away      W   4   2
#
#            opponent  ...   fk   pk  pkatt  season               team  \
# 0       Southampton  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# 1           Chelsea  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# 2            Wolves  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# 3   Nott'ham Forest  ...  0.0  0.0    1.0    2022  Tottenham Hotspur
# 4          West Ham  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# ..              ...  ...  ...  ...    ...     ...                ...
# 54    Sheffield Utd  ...  2.0  0.0    0.0    2020  Tottenham Hotspur
# 55     Leeds United  ...  1.0  0.0    0.0    2020  Tottenham Hotspur
# 56           Wolves  ...  1.0  0.0    0.0    2020  Tottenham Hotspur
# 57      Aston Villa  ...  0.0  0.0    0.0    2020  Tottenham Hotspur
# 58   Leicester City  ...  0.0  0.0    0.0    2020  Tottenham Hotspur
#
#    venue_code opp_code hour  day_code  target
# 0           1       19   15         5       1
# 1           0        6   16         6       0
# 2           1       24   12         5       1
# 3           0       17   16         6       1
# 4           0       23   19         2       0
# ..        ...      ...  ...       ...     ...
# 54          1       18   19         6       1
# 55          0       10   12         5       0
# 56          1       24   14         6       1
# 57          1        1   18         2       0
# 58          0       11   16         6       1
#
# [114 rows x 32 columns]

# %%
def rolling_averages(group,cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3,closed="left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf","ga","sh","sot","dist","fk","pk","pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group,cols,new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 8  2020-10-04  16:30  Premier League   Matchweek 4  Sun  Away      W   6   1
# 9  2020-10-18  16:30  Premier League   Matchweek 5  Sun  Home      D   3   3
# 11 2020-10-26  20:00  Premier League   Matchweek 6  Mon  Away      W   1   0
# 13 2020-11-01  19:15  Premier League   Matchweek 7  Sun  Home      W   2   1
# 15 2020-11-08  12:00  Premier League   Matchweek 8  Sun  Away      W   1   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 45 2023-04-30  16:30  Premier League  Matchweek 34  Sun  Away      L   3   4
# 46 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1   0
# 47 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   1   2
# 48 2023-05-20  12:30  Premier League  Matchweek 37  Sat  Home      L   1   3
# 49 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      W   4   1
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 8   Manchester Utd  ...         6       1    2.000000    1.333333  13.666667
# 9         West Ham  ...         6       0    4.000000    1.333333  17.666667
# 11         Burnley  ...         0       1    3.333333    1.666667  18.333333
# 13        Brighton  ...         6       1    3.333333    1.333333  13.666667
# 15       West Brom  ...         6       1    2.000000    1.333333   9.333333
# ..             ...  ...       ...     ...         ...         ...        ...
# 45       Liverpool  ...         6       0    1.666667    3.666667  17.666667
# 46  Crystal Palace  ...         5       1    2.000000    4.000000  13.000000
# 47     Aston Villa  ...         5       0    2.000000    2.000000  12.000000
# 48       Brentford  ...         5       0    1.666667    2.000000   7.333333
# 49    Leeds United  ...         6       1    1.000000    1.666667  11.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 8     7.666667    14.900000   0.666667    0.000000       0.000000
# 9     8.333333    16.166667   1.000000    0.333333       0.333333
# 11    8.333333    16.966667   1.333333    0.333333       0.333333
# 13    5.333333    16.900000   0.666667    0.333333       0.333333
# 15    3.666667    17.666667   0.666667    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 45    6.000000    17.200000   0.333333    0.000000       0.000000
# 46    5.333333    17.933333   0.000000    0.000000       0.000000
# 47    5.333333    16.433333   0.000000    0.000000       0.000000
# 48    3.333333    17.700000   0.000000    0.333333       0.333333
# 49    3.666667    16.133333   0.000000    0.333333       0.333333
#
# [111 rows x 40 columns]

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2022-08-06  15:00  Premier League   Matchweek 1  Sat  Home      W   4   1
# 1  2022-08-14  16:30  Premier League   Matchweek 2  Sun  Away      D   2   2
# 2  2022-08-20  12:30  Premier League   Matchweek 3  Sat  Home      W   1   0
# 3  2022-08-28  16:30  Premier League   Matchweek 4  Sun  Away      W   2   0
# 4  2022-08-31  19:45  Premier League   Matchweek 5  Wed  Away      D   1   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 54 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Home      W   4   0
# 55 2021-05-08  12:30  Premier League  Matchweek 35  Sat  Away      L   1   3
# 56 2021-05-16  14:05  Premier League  Matchweek 36  Sun  Home      W   2   0
# 57 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Home      L   1   2
# 58 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Away      W   4   2
#
#            opponent  ...   fk   pk  pkatt  season               team  \
# 0       Southampton  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# 1           Chelsea  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# 2            Wolves  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# 3   Nott'ham Forest  ...  0.0  0.0    1.0    2022  Tottenham Hotspur
# 4          West Ham  ...  0.0  0.0    0.0    2022  Tottenham Hotspur
# ..              ...  ...  ...  ...    ...     ...                ...
# 54    Sheffield Utd  ...  2.0  0.0    0.0    2020  Tottenham Hotspur
# 55     Leeds United  ...  1.0  0.0    0.0    2020  Tottenham Hotspur
# 56           Wolves  ...  1.0  0.0    0.0    2020  Tottenham Hotspur
# 57      Aston Villa  ...  0.0  0.0    0.0    2020  Tottenham Hotspur
# 58   Leicester City  ...  0.0  0.0    0.0    2020  Tottenham Hotspur
#
#    venue_code opp_code hour  day_code  target
# 0           1       19   15         5       1
# 1           0        6   16         6       0
# 2           1       24   12         5       1
# 3           0       17   16         6       1
# 4           0       23   19         2       0
# ..        ...      ...  ...       ...     ...
# 54          1       18   19         6       1
# 55          0       10   12         5       0
# 56          1       24   14         6       1
# 57          1        1   18         2       0
# 58          0       11   16         6       1
#
# [114 rows x 32 columns]
